# %%
#@title 按這裡開始（每次上課的第一格都先按 ▶）
print('✅ 恭喜！你成功在手機上執行了第一格程式')
print('本週目標：確認 Colab 能跑，做一張自己的上課證')
print('下一步：往下捲動，一格一格按 ▶')

# %% [markdown]
# # W01 第一次上機
# 手機開這本請先切成「電腦版網站」（iPhone：網址列 ᴀA → 要求電腦版網站；Android：右上 ⋮ → 電腦版網站），再點每一格左邊的 ▶ 執行。
#
# 看到上面印出 ✅ 就代表環境沒問題，往下做四個小任務。

# %% [markdown]
# **任務三之一**：只改右邊表單的 name 和 times，改完「再按一次 ▶」。

# %%
#@title 第一支程式（點左邊的 ▶ 執行）
name = '王小明'   #@param {type:"string"}
times = 3        #@param {type:"integer"}

for i in range(times):
    print(f'{i+1}. 你好，{name}，歡迎來到 AI 的世界')

print('環境正常，你可以開始上課了')

# %% [markdown]
# **任務三之二**：這一格什麼都不用改，確認課程要用的工具都在。

# %%
# 這一格不用改，確認課程要用的工具都在
import sys, numpy, pandas, sklearn

print('Python  ', sys.version.split()[0])
print('NumPy   ', numpy.__version__)
print('Pandas  ', pandas.__version__)
print('sklearn ', sklearn.__version__)

# %% [markdown]
# **任務三之三**：把 n 改成 10、50、1000 各跑一次，把三個答案記下來。

# %%
n = 100  #@param {type:"integer"}

total = sum(range(1, n + 1))
print(f'1 加到 {n} 的總和是 {total}')

# 小技巧：長按輸出區的文字可以直接複製

# %% [markdown]
# **做一張上課證**：把姓名與學號改成自己的，跑出來的卡片要截圖交表單。

# %%
#@title 做一張你的上課證（改成自己的資料再按 ▶）
姓名 = '請改成你的名字'   #@param {type:"string"}
學號 = 'B11390000'      #@param {type:"string"}

print('┌' + '─' * 26 + '┐')
print('  AI 導論 115-1 上課證')
print(f'  姓名：{姓名}')
print(f'  學號：{學號}')
print('└' + '─' * 26 + '┘')
print('✅ 截圖這張卡，等一下交課程表單要用')

# %% [markdown]
# **小互動**：答案藏在你的學號裡，拉滑桿猜，猜錯再猜一次。

# %%
#@title 小互動：猜幸運數字（拉滑桿猜 1～10）
猜的數字 = 7  #@param {type:"slider", min:1, max:10, step:1}

import random
random.seed(學號)              # 每個學號的答案都不一樣
答案 = random.randint(1, 10)
if 猜的數字 == 答案:
    print(f'🎉 猜中了！{學號} 的幸運數字就是 {答案}')
else:
    print(f'沒中喔，答案是 {答案}。改滑桿再按一次 ▶ 就會中')
print('✅ 本週上機完成：截圖「上課證」上傳課程表單')
