# %%
#@title 按這裡開始（先按 ▶）
print('✅ W01 出發！本週目標：把筆記本變成自己的，再自己寫出第一支 Python 程式')
print('電腦教室版：關鍵的那幾行要你自己用鍵盤打出來，不要複製別人的答案。')

# %% [markdown]
# # W01　Colab 環境設定與第一支自己寫的程式
#
# **動手之前先做這一步**：`檔案 → 在雲端硬碟中儲存副本`，再把檔名改成
# `AI導論_W01_學號_姓名`。沒存副本就改，改完不會存，下課就全部消失。
#
# - 執行這一格：`Ctrl + Enter`；執行後跳下一格：`Shift + Enter`
# - 左側 `{x}` 是變數檢視器，看得到現在有哪些變數
# - 遇到 `____` 就是**你要自己寫**的地方，不要留著原樣執行
# - 卡超過 5 分鐘就舉手，先講出錯誤訊息的**最後一行**是什麼

# %% [markdown]
# ## 任務二之二：變數還在不在？（第 1 格）
#
# 先照順序執行這一格與下一格，再試一次「執行階段 → 重新啟動工作階段」。
#
# **寫對了會看到**：`1 加到 100 = 5050`

# %%
# 第 1 格：先執行這一格
total = 0
for i in range(1, 101):
    total += i
print('1 加到 100 =', total)

# %% [markdown]
# ### 任務二之二（第 2 格）
#
# 這一格用到上面那一格算好的 `total`。先正常執行一次，接著
# 「執行階段 → 重新啟動工作階段」，**只跑這一格**，看看會發生什麼事。
#
# **會看到**：重新啟動後只跑第 2 格會出現 `NameError`，因為變數被清空了。

# %%
# 第 2 格：這一格用到上面算好的 total
print('total 現在是', total)
# 重新啟動工作階段之後，只跑第 2 格會發生什麼事？

# %% [markdown]
# ## 任務三：自己寫 5 行，印出你的上課證
#
# 下面 5 個 `____` 都要換成你自己寫的東西，**不要複製別人的**。
#
# **寫對了會看到**：印出三行，最後一行是今天日期，例如 `日期： 2026-09-15`。

# %%
from datetime import date

name = ____          # ① 你的名字，記得用引號包起來
sid  = ____          # ② 你的學號，一樣要加引號
today = ____         # ③ 今天日期，提示：date.today()

print('=== AI 導論 上課證 ===')
print(____, ____)    # ④ 印出學號與姓名
print('日期：', ____) # ⑤ 印出今天的日期

# %% [markdown]
# ## 任務五（進階）：把「訂規則」寫成 if/else
#
# 用理論那 5 封信。**只要填中間那一行的條件**。
#
# **寫對了會看到**：`答對 4 ／5　正確率 0.8`，和理論的規則 C 完全一樣。

# %%
mails = ['限時免費 點此領取', '免費試用 名額有限',
         '恭喜中獎 點此登記', '社團免費講座報名',
         '作業檔案 請查收']
ans = ['垃圾', '垃圾', '垃圾', '正常', '正常']

right = 0
for m, a in zip(mails, ans):
    guess = '垃圾' if ____ else '正常'   # ← 這一行你自己寫
    if guess == a:
        right += 1

print('答對', right, '／5　正確率', right / 5)

# %% [markdown]
# ## 任務四：存檔、下載與繳交
#
# 下課前一定要完成 —— 教室電腦還原之後就救不回來了。
#
# 1. **確認左上角顯示「已儲存」**：按一次 `Ctrl + S` 最保險，檔名要是 `AI導論_W01_學號_姓名`
# 2. **檔案 → 下載 → 下載 .ipynb**：下載到電腦只是備份，真正要交的是雲端硬碟的連結
# 3. **共用 → 改成「知道連結的人可以檢視」**：沒改權限，老師點開只會看到「你需要存取權」
# 4. **把連結與一張截圖交到課程表單**：截圖要同時看得到上課證的輸出與左上角的檔名
#
# ### 延伸挑戰（A 到 C 越後面越難）
#
# - **A 改參數再跑**：把上課證那一格改成同時印出「今天是星期幾」。提示：`date.today().weekday()`。
# - **B 換一種做法**：任務五改成「兩個詞都出現才判垃圾」，正確率變成多少？和規則 C 比一比。
# - **C 說出為什麼**：規則 C 只錯一封，為什麼還是不夠好？如果對方把「免費」寫成「免 費」，你的規則還抓得到嗎？

# %% [markdown]
# ---
#
# <details>
# <summary><b>參考解</b>（真的卡住再打開，先自己試滿 10 分鐘）</summary>
#
# **任務三**
#
# ```python
# name = '王小明'          # 換成你自己的名字
# sid  = '41B12345'        # 換成你自己的學號
# today = date.today()
#
# print('=== AI 導論 上課證 ===')
# print(sid, name)
# print('日期：', today)
# ```
#
# **任務五**（規則 C：兩個關鍵詞出現任一個就判垃圾）
#
# ```python
# guess = '垃圾' if ('免費' in m or '點此' in m) else '正常'
# ```
#
# B 級挑戰的「兩個詞都出現才擋」是規則 B，改成 `and` 之後只會答對 3／5。
#
# </details>
