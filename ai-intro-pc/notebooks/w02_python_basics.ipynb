# %%
#@title 按這裡開始（先按 ▶）
print('✅ W02 出發！本週目標：自己寫出 for 迴圈、if/elif 判斷與一個有回傳值的函式')
print('遇到 ____ 就是你要自己打字的地方；括號、引號、冒號一律用半形。')

# %% [markdown]
# # W02　自己寫出迴圈、判斷與函式
#
# **開始之前的五個約定**
#
# 1. **先存副本再動手**：`檔案 → 在雲端硬碟中儲存副本`，檔名改成 `AI導論_W02_學號_姓名`
# 2. **一人一機自己打**：可以問組員，但不可以複製貼上別人的答案
# 3. **改完就 `Ctrl + Enter`**：沒重新執行，變數還是上一次的舊值
# 4. **錯誤先看最後一行**：最後一行才是錯誤類型，上面那一大串是追蹤路徑
# 5. **卡超過 5 分鐘舉手**：先講出錯誤訊息的最後一行是什麼
#
# 常用快速鍵：`Ctrl+Enter` 執行這一格、`Shift+Enter` 執行後跳下一格、
# `Ctrl+M` 再按 `B` 在下面插入新格、`執行階段 → 中斷執行` 停掉跑不停的程式。

# %% [markdown]
# ## 任務一：變數與型別（先看，再改）
#
# 先**原封不動**跑一次，再把三個值改成你自己的。
#
# **會看到**：四個值、三個型態，以及「明年 20 歲」。

# %%
name = '王小明'      # 字串 str
age = 19             # 整數 int
height = 172.5       # 浮點數 float
is_freshman = True   # 布林 bool

print(name, age, height, is_freshman)
print(type(name), type(age), type(height))
print('明年', age + 1, '歲')

# 想一想：把 age 改成 '19'（加引號）會怎樣？

# %% [markdown]
# **想一想的答案**：改成 `'19'` 之後 `age + 1` 會報 `TypeError`，這就是型態的差別。
#
# ---
#
# ## 任務二：自己寫 for 迴圈印出乘法表
#
# 外層迴圈已經寫好，**內層那兩個 `____` 你自己補**。
#
# **寫對了會看到**：印出 2 到 9 共八段，最後一行是 `9 x 9 = 81`。

# %%
n = 9   # 要印到幾的乘法表

for i in range(2, n + 1):
    print(f'--- {i} 的乘法 ---')
    for j in range(____, ____):       # ← ① 從 1 到 9
        print(f'{i} x {j} = {____}')  # ← ② 乘出來的答案

# %% [markdown]
# ### 程式跑不動時，照這三步驟看
#
# 1. **先看最後一行**：最後一行才是錯誤類型與說明
# 2. **再看行號與箭頭**：訊息會指出第幾行，回去看那一行以及它的上一行
# 3. **認得三個常見錯**：`SyntaxError` 語法打錯、`NameError` 變數不存在、`IndentationError` 縮排不對
#
# ---
#
# ## 任務三：自己寫 if/elif 做成績分級
#
# 三個判斷條件由你自己寫，**特別注意順序**。
#
# **寫對了會看到**：五個分數依序是 `A B C 不及格 C`；60 分要判成 C。

# %%
scores = [95, 82, 71, 58, 60]

for s in scores:
    if ____:              # ← ① 90 分以上
        grade = 'A'
    elif ____:            # ← ② 80 到 89
        grade = 'B'
    elif ____:            # ← ③ 60 到 79
        grade = 'C'
    else:
        grade = '不及格'
    print(s, grade)

# %% [markdown]
# ## 任務四：自己寫一個有回傳值的函式
#
# `def` 那一行、算式與 `return` 都要你自己寫。
#
# **寫對了會看到**：`22.0` 與 `17.6`；對不上就檢查有沒有先把公分換成公尺。

# %%
def bmi(h_cm, w_kg):       # ← ① 參數已經幫你命名好，不要改
    m = h_cm / 100         # 公分換算成公尺
    value = ____           # ← ② BMI ＝ 體重 ÷ 身高平方（用 w_kg 和 m）
    return ____            # ← ③ 把 value 交回給呼叫的人

print(round(bmi(172, 65), 1))   # 應該印出 22.0
print(round(bmi(160, 45), 1))   # 應該印出 17.6

# %% [markdown]
# ## 任務五（進階）：while 猜數字
#
# 繼續猜的條件與太小的條件，**兩個都要自己寫**。
#
# **寫對了會看到**：猜中會印出你猜了幾次。忘了 `break` 就變成無窮迴圈，
# 用「執行階段 → 中斷執行」停掉它。輸入框會出現在輸出區下方，點一下再打字。

# %%
import random
answer = random.randint(1, 100)
count = 0

while ____:               # ← ① 什麼時候要繼續猜
    g = int(input('猜一個 1 到 100 的整數：'))
    count += 1
    if g > answer:
        print('太大了')
    elif ____:            # ← ② 猜太小的情況
        print('太小了')
    else:
        print('答對了，你猜了', count, '次')
        break

# %% [markdown]
# ## 繳交：這一週要交什麼
#
# 四段程式放在同一份筆記本裡，最後只要交一個連結。
#
# 1. **四格程式都要跑得出正確輸出**：型別、乘法表、成績分級、BMI 函式，缺一格就少一項
# 2. **每格上方加一行註解寫學號姓名**：格式 `# 41B12345 王小明　任務二`
# 3. **確認「已儲存」，再改共用權限**：共用 → 知道連結的人可以檢視
# 4. **把連結交到課程 Google 表單**：做完任務五的人，在備註欄寫「已完成任務五」
#
# ### 延伸挑戰（A 到 C 越後面越難）
#
# - **A 改參數再跑**：把乘法表的 `n` 改成 12，而且只印偶數段（2、4、6…）。提示：`range` 的第三個參數。
# - **B 換一種做法**：成績分級改成用 `dict` 存門檻，再用 `for` 走過去判斷，不要寫一長串 `elif`。
# - **C 說出為什麼**：把 `bmi()` 裡的 `return` 刪掉再跑一次，印出來會是 `None`。說明 `return` 到底做了什麼。

# %% [markdown]
# ---
#
# <details>
# <summary><b>參考解</b>（真的卡住再打開，先自己試滿 10 分鐘）</summary>
#
# **任務二**
#
# ```python
#     for j in range(1, 10):
#         print(f'{i} x {j} = {i * j}')
# ```
#
# **任務三**（順序很重要：先擋掉大的，後面才不用寫「而且小於」）
#
# ```python
#     if s >= 90:
#         grade = 'A'
#     elif s >= 80:
#         grade = 'B'
#     elif s >= 60:
#         grade = 'C'
# ```
#
# **任務四**
#
# ```python
# def bmi(h_cm, w_kg):
#     m = h_cm / 100
#     value = w_kg / (m ** 2)
#     return value
# ```
#
# **任務五**
#
# ```python
# while True:            # ① 一直猜到 break 為止
#     ...
#     elif g < answer:   # ② 猜太小
# ```
#
# </details>
